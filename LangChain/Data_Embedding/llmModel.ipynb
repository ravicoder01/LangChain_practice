# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['GROQ_API_KEY'] = os.getenv('GROQ_API_KEY')
os.environ['LANGCHAIN_API_KEY'] = os.getenv('LANGCHAIN_API_KEY')
os.environ['LANGCHAIN_PROJECT'] = os.getenv('LANGCHAIN_PROJECT')

# %%
from langchain_groq import ChatGroq

llm= ChatGroq(
    model= "llama-3.3-70b-versatile"
)
print(llm)
# Out:
# output_version=None profile={'max_input_tokens': 131072, 'max_output_tokens': 32768, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True} client=<groq.resources.chat.completions.Completions object at 0x000001B882DA2770> async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000001B882DA2E60> model_name='llama-3.3-70b-versatile' model_kwargs={} groq_api_key=SecretStr('**********') groq_api_base=None groq_proxy=None

# %% [markdown]
# Input and getting response

# %%
llm.invoke("What is the capital of France?")
# Out:
# AIMessage(content='The capital of France is Paris.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 42, 'total_tokens': 50, 'completion_time': 0.010496141, 'completion_tokens_details': None, 'prompt_time': 0.003931932, 'prompt_tokens_details': None, 'queue_time': 0.163808096, 'total_time': 0.014428073}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_3272ea2d91', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019e846c-21ae-72d2-a8ff-e4b6683a31f7-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 42, 'output_tokens': 8, 'total_tokens': 50})

# %%
llm.invoke("What is AI?")
# Out:
# AIMessage(content='**Artificial Intelligence (AI)** is a field of computer science that focuses on creating intelligent machines capable of performing tasks that typically require human intelligence. These tasks include:\n\n* Learning\n* Problem-solving\n* Reasoning\n* Perception\n* Understanding language\n\nAI involves the development of algorithms, statistical models, and computer programs that enable machines to:\n\n1. **Process and analyze large amounts of data**\n2. **Make decisions or predictions**\n3. **Automate tasks**\n4. **Interact with humans**\n\nThe primary goals of AI are to:\n\n1. **Mimic human intelligence**: Create machines that can think and act like humans.\n2. **Improve efficiency**: Automate tasks to reduce time and increase productivity.\n3. **Enhance decision-making**: Provide machines with the ability to make informed decisions.\n\nAI has numerous applications across various industries, including:\n\n1. **Healthcare**: Medical diagnosis, personalized medicine, and patient care.\n2. **Finance**: Risk management, portfolio optimization, and trading.\n3. **Transportation**: Autonomous vehicles, route optimization, and traffic management.\n4. **Customer Service**: Chatbots, virtual assistants, and sentiment analysis.\n\nThere are several types of AI, including:\n\n1. **Narrow or Weak AI**: Designed to perform a specific task, such as image recognition or language translation.\n2. **General or Strong AI**: Aims to create machines that can perform any intellectual task that a human can.\n3. **Superintelligence**: Exceeds human intelligence in many domains, potentially leading to significant advancements or risks.\n\nAs AI continues to evolve, it has the potential to revolutionize numerous aspects of our lives, from healthcare and education to transportation and entertainment.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 346, 'prompt_tokens': 39, 'total_tokens': 385, 'completion_time': 0.867650701, 'completion_tokens_details': None, 'prompt_time': 0.001819631, 'prompt_tokens_details': None, 'queue_time': 0.059665089, 'total_time': 0.869470332}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019e846c-b1e8-7a33-b887-ac49ddf54dcc-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 39, 'output_tokens': 346, 'total_tokens': 385})

# %% [markdown]
# # Chat Prompt (instruct model to behave like something)

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt= ChatPromptTemplate.from_messages(
    [
         ("system", "You are an AI expert engineer. Provide me answer based on question"),
         ("user", "{input}")
    
    ]
)
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an AI expert engineer. Provide me answer based on question'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
chain= prompt| llm
result= chain.invoke({"input": "what is the use of capacitor?"})
result
# Out:
# AIMessage(content="As an AI expert engineer, I'd be happy to explain the uses of a capacitor.\n\nA capacitor is a fundamental component in electronic circuits, and its primary function is to store electrical energy in the form of an electric field. The uses of a capacitor are numerous and varied, but some of the most common applications include:\n\n1. **Filtering**: Capacitors are used to filter out unwanted frequencies or noise from a signal, allowing only the desired frequencies to pass through.\n2. **Power Supply Filtering**: Capacitors are used to smooth out the output of a power supply, reducing ripple and noise, and providing a stable DC voltage.\n3. **Coupling**: Capacitors are used to couple signals between different stages of a circuit, allowing AC signals to pass through while blocking DC signals.\n4. **Energy Storage**: Capacitors can store electrical energy, which can be released quickly when needed, making them useful for applications such as flash photography, laser technology, and audio equipment.\n5. **Timing and Oscillation**: Capacitors are used in timing circuits, such as oscillators and timers, to control the frequency and duration of signals.\n6. **Voltage Regulation**: Capacitors can be used to regulate voltage levels in a circuit, helping to maintain a stable voltage supply.\n7. **Noise Reduction**: Capacitors can be used to reduce electromagnetic interference (EMI) and radio-frequency interference (RFI) in circuits.\n8. **Audio Equipment**: Capacitors are used in audio equipment, such as speakers, amplifiers, and equalizers, to improve sound quality and reduce distortion.\n9. **Power Factor Correction**: Capacitors are used to correct the power factor in AC circuits, improving the efficiency of power transmission and reducing energy losses.\n10. **Medical Equipment**: Capacitors are used in medical equipment, such as defibrillators, pacemakers, and ultrasound machines, to store and release electrical energy.\n\nThese are just a few examples of the many uses of capacitors. The specific application of a capacitor depends on its characteristics, such as its capacitance value, voltage rating, and type (e.g., ceramic, electrolytic, or film).", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 435, 'prompt_tokens': 55, 'total_tokens': 490, 'completion_time': 1.213084024, 'completion_tokens_details': None, 'prompt_time': 0.005199207, 'prompt_tokens_details': None, 'queue_time': 0.161764112, 'total_time': 1.218283231}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_3272ea2d91', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019e871a-c092-75a3-8b78-a023550c36ba-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 55, 'output_tokens': 435, 'total_tokens': 490})
